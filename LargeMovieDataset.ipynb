# %% [markdown]
# # Import everything

# %%
import os, sys
import tensorflow as tf
from tqdm import tqdm_notebook as tqdm
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd

if not os.path.exists('aclImdb_v1.tar.gz'):
    # !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz

x_train = np.load('/content/data/train/neg')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-16-49ac46e5cf5e> in <module>()
#      10     get_ipython().system('wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz')
#      11
# ---> 12 x_train = np.load('/content/data/train/neg')
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/data/train/neg'

# %%
x_train_full, y_train_full, x_test, y_test = train_test_split(movie_df)
